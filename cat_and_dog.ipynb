# %% [markdown]
# <a href="https://colab.research.google.com/github/Hrushikeshhad123/catvsdog/blob/main/cat_and_dog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install simple_image_download
# Out:
# ...
# INFO: pip is looking at multiple versions of simple-image-download to determine which version is compatible with other requirements. This could take a while.
# ...

# %%
from simple_image_download import simple_image_download as simp

response =simp.simple_image_download

# %%
keyword = ['cats']

for kw in keyword:
  response().download(kw,50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-15ea14eade32> in <cell line: 3>()
#       2
#       3 for kw in keyword:
# ----> 4   response().download(kw,50)
#
# /usr/local/lib/python3.10/dist-packages/simple_image_download/simple_image_download.py in download(self, keywords, limit)
#      92
#      93                 try:
# ---> 94                     r = requests.get(object_raw, allow_redirects=True)
#      95                     open(os.path.join(path, filename), 'wb').write(r.content)
#      96                 except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
# ...

# %%
import shutil

# Path to the folder you want to zip
folder_path = '/content/simple_images'

# Path for the zip file to be created
zip_file_path = '/content/simple_images.zip'

# Create a Zip file
shutil.make_archive(zip_file_path, 'zip', folder_path)

print(f'Zip file created at: {zip_file_path}')
# Out:
# Zip file created at: /content/simple_images.zip

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.2/661.2 kB 4.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 221MB/s]

# %%
model.train(data = '/content/Untitled Folder/data.yaml',batch=8,imgsz=640,epochs=20,workers=1)
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('/content/runs/detect/train/weights/best.pt')

model.predict(source='/content/Untitled Folder/😾The Most HILARIOUS Cats Vs Dogs! 🐶.mp4',show=True,save=True,conf=0.5)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1744) /content/Untitled Folder/😾The Most HILARIOUS Cats Vs Dogs! 🐶.mp4: 640x384 (no detections), 149.9ms
# video 1/1 (2/1744) /content/Untitled Folder/😾The Most HILARIOUS Cats Vs Dogs! 🐶.mp4: 640x384 (no detections), 25.1ms
# video 1/1 (3/1744) /content/Untitled Folder/😾The Most HILARIOUS Cats Vs Dogs! 🐶.mp4: 640x384 (no detections), 25.5ms
# ...
